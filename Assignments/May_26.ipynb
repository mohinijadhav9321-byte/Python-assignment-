# %%
name = "sayali"
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# True

# %%
name = "sayali"
name.istitle()
# Out:
# False

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name = "sayali"
name.startswith("s")
# Out:
# True

# %%
name.endswith("s")
# Out:
# False

# %%
name1 = " sayali"
name1.strip()
# Out:
# 'sayali'

# %%
len(name1)
# Out:
# 7

# %%
name1.replace("s","j")
# Out:
# ' jayali'

# %%
a = 9
b = 6

a + b
a - b
a / b
a ** b
b // a
b % a
# Out:
# 6

# %%
a > b
a < b
a == b
a >= b
a != b
# Out:
# True

# %%
a = True
b = False

a and b
a or b
not a
not b
# Out:
# True

# %%
a = [3,4]
b = [3,4]

a is b
a is not b
# Out:
# True

# %%
l = [1,2,3,4]

1 in l
5 not in l
# Out:
# True
