# %%
print("Hello World")
# Out:
# Hello World

# %%
num = 87
num1 = 90
name = "riya"
print(name)
# Out:
# riya

# %%
a = 23
b = 23.4
c = "sayali"

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
num = 23e4
print(num)
# Out:
# 230000.0

# %%
sent = 'i "like" python programming'
print(sent)
# Out:
# i "like" python programming

# %%
sent = "i like 'python' programming"
print(sent)
