# %%
l=[12,34,56,78]

# %%
print(l)
# Out:
# [12, 34, 56, 78]

# %%
l1=[12,34,56,"Python","Java",1.34]

# %%
print(l1)
# Out:
# [12, 34, 56, 'Python', 'Java', 1.34]

# %%
# list are ordered

# %%
l1
# Out:
# [12, 34, 56, 'Python', 'Java', 1.34]

# %%
l1[2]
# Out:
# 56

# %%
l1[-3]
# Out:
# 'Python'

# %%
#list are mutable

# %%
l1[1]
# Out:
# 34

# %%
l1[1]=100

# %%
print(l1)
# Out:
# [12, 100, 56, 'Python', 'Java', 1.34]

# %%
l1[-2]
# Out:
# 'Java'

# %%
l1[-2]=True

# %%
print(l1)
# Out:
# [12, 100, 56, 'Python', True, 1.34]

# %%
#list slicing

# %%
l2=[21,23,45,67,89,11]

# %%
12
# Out:
# 12

# %%
l2[1:4]
# Out:
# [23, 45, 67]

# %%
l2[1:-2]
# Out:
# [23, 45, 67]

# %%
l2[0:6:2]
# Out:
# [21, 45, 89]

# %%
l2[::2]
# Out:
# [21, 45, 89]

# %%
l2[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l2[1:4]=100,200,300

# %%
12
# Out:
# 12
