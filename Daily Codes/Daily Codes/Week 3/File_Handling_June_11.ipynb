# %%
"""
Create a sample file with some text in it
""";

# %%
#open the file

# %%
f = open("Sample.txt", "w")
f.write("Hello World")
f.close()

# %%
f = open("Sample.txt", "r")
print(f.read())
f.close()
# Out:
# Hello World

# %%
f=open ("Sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='Sample.txt' mode='r' encoding='utf-8'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'Hello World'

# %%
f.readline()
# Out:
# ''

# %%
f=open("Sample.txt")

# %%
f.readline(10)
# Out:
# 'Hello Worl'

# %%
f.readline(5)
# Out:
# 'd'

# %%
f=open("Sample.txt")

# %%
data=f.readlines()

# %%
data
# Out:
# ['Hello World']

# %%
for line in data:
    print(line)
# Out:
# Hello World

# %%
# convert the data to uppercase

# %%
for line in data:
    print(line.upper())
# Out:
# HELLO WORLD

# %%
# read

# %%
f=open("Sample.txt")

# %%
text=f.read()

# %%
text
# Out:
# 'Hello World'

# %%
print(text)
# Out:
# Hello World

# %%
text.split()
# Out:
# ['Hello', 'World']

# %%
f = open("Marathi.txt", "w", encoding="utf-8")
f.write("मराठी भाषा ही भारतातील एक प्रमुख भाषा आहे.")
f.close()

# %%
f = open("Marathi.txt", "r", encoding="utf-8")
print(f.read())
f.()
# Out:
# मराठी भाषा ही भारतातील एक प्रमुख भाषा आहे.

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='Marathi.txt' mode='r' encoding='utf-8'>

# %%
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
f.readable()
# Out:
# False

# %%
# writing in a file

# %%
f=open("Sample.txt",'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines=['frodo took the ring','he startedf.writelines(lines) his journey to mount doom']

# %%
f.writelines(lines)

# %%
f.close()

# %%
# writelines

# %%
#write

# %%
sent = 'frodo took the ring, he started his journey to mount doom'

# %%
f=open("Sample.txt",'w')
f.write(sent)
f.close()

# %%
with open('myfile.txt','w') as f:
    f.write("This is first line\n")
    f.write("This is second\n")
    f.write("This is third")

# %%
s=open("Sample.txt",'r')
f=open("myfile.txt",'w')

# %%
contents=s.read()
f.write(contents)
f.close()

# %%
# append

# %%
s=open("Sample.text",'a')

# %%
s.write("\nDone")
# Out:
# 5

# %%
s.close()
